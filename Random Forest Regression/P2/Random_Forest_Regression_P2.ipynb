# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv('Housing.csv')
X = dataset.iloc[:, 1:].values
y = dataset.iloc[:, 0].values
y = y.reshape(len(y), 1)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
ct = ColumnTransformer(transformers = [('encoder', OneHotEncoder(), [4,5,6,7,8,10,11])], 
                       remainder = 'passthrough')
X = np.array(ct.fit_transform(X))
# Out:
# [[3620 2 1 ... 0 'no' 'unfurnished']
#  [4000 2 1 ... 0 'no' 'unfurnished']
#  [3040 2 1 ... 0 'no' 'unfurnished']
#  ...
#  [5750 3 2 ... 1 'yes' 'unfurnished']
#  [3600 3 1 ... 1 'no' 'unfurnished']
#  [6600 3 1 ... 0 'yes' 'furnished']]

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
ct = ColumnTransformer(transformers = [('encoder', OneHotEncoder(), [4,5,6,7,8,10,11])], 
                       remainder = 'passthrough')
X = np.array(ct.fit_transform(X))

# %%
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 10, random_state = 0)
regressor.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 3
#       1 from sklearn.ensemble import RandomForestRegressor
#       2 regressor = RandomForestRegressor(n_estimators = 10, random_state = 0)
# ----> 3 regressor.fit(X_train, y_train)
#
# File D:\Anaconda\Lib\site-packages\sklearn\base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File D:\Anaconda\Lib\site-packages\sklearn\ensemble\_forest.py:359, in BaseForest.fit(self, X, y, sample_weight)
#     356 if issparse(y):
# ...

# %%
y_pred = regressor.predict(X_test)
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

# %%
y_train_pred = regressor.predict(X_train)
np.set_printoptions(precision=2)
print(np.concatenate((y_train_pred.reshape(len(y_train_pred),1), 
                      y_train.reshape(len(y_train),1)), 1))
